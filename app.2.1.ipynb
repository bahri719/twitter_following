# %% [markdown]
# # initializing and imports

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from transformers import pipeline
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import inspect
import re
import time

# غیرفعال کردن هشدار MarkupResemblesLocatorWarning
import warnings
from bs4 import MarkupResemblesLocatorWarning
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %%
hunting = 0  #  شیئی گروه برای ارسال پیام های یافت شده
previous_messages = []  #  زمان ارسال پیام های قبل برای جلوگیری از ارسال مجدد آن ها
sending_messages=[]  #  پیام های یافت شده را در این نگه میداریم تا زمان ارسال و بعد مجددا خالی اش می کنیم
chat_title=''
chat_id=''
timestamp = ''
driver = webdriver.Chrome()
driver.get("https://web.telegram.org/k/")

# %%
# بارگذاری مدل و توکنایزر ذخیره شده
model_path = "ai_model"
tokenizer_path = "ai_tokenizer"

# ایجاد pipeline برای دسته‌بندی توالی
classifier = pipeline("sentiment-analysis", model=model_path, tokenizer=tokenizer_path)

# %% [markdown]
# # Text Processing

# %% [markdown]
# ### AI Model for distinguishing the text

# %%
# چک می کند که آیا پیام حاوی درخواستی برای معرفی وکیل یا مشاور مهاجرتی هست یا خیر
#  مدل قبل آموزش داده شده و همه جملات شامل مشاور یا وکیل را مورد بررسی قرار میده
# اگر جمله مرتبط تشخیص داده نشود برای چت خودم ارسالش می کند تا مطمئن باشم که درست عمل شده
def ai(text, min_score = 0.7):
    result = classifier(text)
    label = result[0]['label']
    score = result[0]['score']
    if(label == 'LABEL_1' and score > min_score):
        return True
    else:
        send_message_bot(text, 'me')
        return False

# %% [markdown]
# ### text_processing

# %%
#  تابع پردازش پیام ها
def text_processing(text):
    if(text == []):
        return False
    positive_expression =['منصوری','روادید',]

    negetive_expression =['تماس بگیرید','لطفا جهت کسب اطلاعات',
                          'خدمات ما شامل', 'لطفا جهت ثبت نام']
    
    necessary_expression = ['مشاور','وکیل','مشاوره',]
    
    for expression in negetive_expression:
        if expression in text:
            return False
        
    for expression in positive_expression:
        if expression in text:
            return True
    
    for expression in necessary_expression:
        if expression in text:
            if (ai(text)):
                return True
            else:
                return False
    
    return False

# %% [markdown]
# ### remove_html_and_patterns

# %%
def remove_html_and_patterns(text):
    # مرحله 1: حذف تگ‌های HTML
    soup = BeautifulSoup(text, "html.parser")
    clean_text = soup.get_text()

    # مرحله 2: حذف الگوهای خاص
    patterns = [
        r'\b\w*\.png\b',  # الگو برای *.png
        r'\bclass\w*\b',  # الگو برای class*
        r'\b\w*emoji\w*\b'  # الگو برای *emoji*
    ]
    
    for pattern in patterns:
        clean_text = re.sub(pattern, '', clean_text)

    # مرحله 3: حذف فاصله‌های اضافی
    clean_text = ' '.join(clean_text.split())

    return clean_text

# %% [markdown]
# ### clean_message

# %%
#اینترها را قبل از ارسال پیام با اسپیس جایگزین کند
def clean_message(text):
    # Replace all newline characters with a space
    text = text.replace('\n', ' ')
    # Split the text by any whitespace and rejoin with a single space
    cleaned_text = ' '.join(text.split())
    return cleaned_text

# %% [markdown]
# # Dive in HTML

# %% [markdown]
# ## Finding Things

# %% [markdown]
# ### is_a_super_group_open

# %%
# بررسی می کند که آیا دکمه سوپر گروه باز است و درست یا غلط برمیگرداند
def is_a_super_group_open():
    try:
        if(driver.find_element(By.CSS_SELECTOR, "button.btn-icon.sidebar-close-button").find_element(By.CSS_SELECTOR,"span.tgico.button-icon")):
            return False
    except:
            return True

# %% [markdown]
# ### find_list_of_all_chats

# %%
#  ساختن لیستی از کل چت های موجود    
def find_list_of_all_chats():
    close_super_group_button()
    return driver.find_elements(By.CSS_SELECTOR, "a.row.no-wrap.row-with-padding.row-clickable.hover-effect.rp.chatlist-chat.chatlist-chat-bigger.row-big")

# %% [markdown]
# ### find_list_of_all_sub_chats

# %%
#  ساختن لیستی از کل زیر چت های موجود    
def find_list_of_all_sub_chats():
    return driver.find_elements(By.CSS_SELECTOR,'ul.chatlist')[1] \
        .find_elements(By.CSS_SELECTOR,"a.row.no-wrap.row-clickable.hover-effect.rp.chatlist-chat.chatlist-chat-bigger.row-big")

# %% [markdown]
# ### find_chat_title_and_id

# %%
#  یافتن عنوان و آیدی چت
def find_chat_title_and_id(chat):
    return [chat.find_element(By.CSS_SELECTOR,"div.row-title.no-wrap.user-title")\
                .find_element(By.CSS_SELECTOR,"span.peer-title")\
                .text ,\
            chat.find_element(By.CSS_SELECTOR,"div.row-title.no-wrap.user-title")\
                .find_element(By.CSS_SELECTOR,"span.peer-title") \
                .get_attribute('data-peer-id')]

# %% [markdown]
# ### find_sub_chat_title_and_id

# %%
#  یافتن عنوان و آیدی زیرچت
def find_sub_chat_title_and_id(chat):
    return [chat.find_element(By.CSS_SELECTOR,"div.row-title.no-wrap.user-title")\
                .find_element(By.CSS_SELECTOR,"span.peer-title")\
                .text ,\
            chat.find_element(By.CSS_SELECTOR,"div.row-title.no-wrap.user-title")\
                .find_element(By.CSS_SELECTOR,"span.peer-title") \
                .get_attribute('data-peer-id')+\
            chat.find_element(By.CSS_SELECTOR,"div.row-title.no-wrap.user-title")\
                .find_element(By.CSS_SELECTOR,"span.peer-title") \
                .get_attribute('data-thread-id')]

# %% [markdown]
# ### is_there_unread_message

# %%
#  چک می کند که آیا در این چت پیام خوانده نشده وجود دارد یا خیر
def is_there_unread_message(chat):
    try:
        if(chat.find_element(By.CSS_SELECTOR,"div.dialog-subtitle-badge.badge.badge-22.dialog-subtitle-badge-unread.is-visible.unread").text):
            return True  #  اگر این چت تگ پیام خوانده نشده داشته باشد مقدار تورو را برمگرداند وگرنه مقدار فالس را
    except:
        return False

# %% [markdown]
# ### check_if_message_is_new

# %%
def check_if_message_is_new():
    global previous_messages, chat_id, timestamp
   
    is_new = True # آیا آی دی گروه جدید است؟
    for row in range(len(previous_messages)):
        if(previous_messages[row][0] == chat_id):
            is_new = False
            break
    if(is_new):
        previous_messages.append([])
        previous_messages[len(previous_messages) - 1].append(chat_id)
        row += 1

    for col in range(len(previous_messages[row])):
        if (previous_messages[row][col] == timestamp):
            return False
    
    previous_messages[row].append(timestamp)
    return True

# %% [markdown]
# ## Do Something

# %% [markdown]
# ### close_super_group_button

# %%
# این تابع دکمه بستن سوپر گروه ها را اگر باز شده باشند می زند تا بسته شود
def close_super_group_button():
        try:
                super_group_button = driver.find_element(By.CSS_SELECTOR, "button.btn-icon.sidebar-close-button")
                super_group_button.click()
        except:
                {}

# %% [markdown]
# ### scroll_down

# %%
# با فراخوانی این تابع دکمه اسکرول داون در صورت وجود فشرده می شود
def scroll_down():
    scroll_down_button = driver.find_element(By.CSS_SELECTOR, ".btn-circle.btn-corner.z-depth-1.bubbles-corner-button.chat-secondary-button.bubbles-go-down.rp")
    try:
        scroll_down_button.click()
        time.sleep(3)
    except:
        {}

# %% [markdown]
# ### clicking

# %%
def clicking(item):
    try:
        item.click()
        return False   # it means there is no problem in clicking the item
    except:
        time.sleep(10)
        try:
            item.click()
            return False   # it means there is no problem in clicking the item
        except:
            return True   # it means there is a problem in clicking the item

# %% [markdown]
# # Axiliary Functions

# %% [markdown]
# ### warm_up

# %%
def warm_up():
    global chat_id, chat_title
    global previous_messages
    chats = find_list_of_all_chats()
    for chat in chats:
        [chat_title, chat_id] = find_chat_title_and_id(chat)
        if not(redundent_chats(chat_id)):
            previous_messages.append([chat_id])

# %% [markdown]
# ### redundent_chats

# %%
#  چت هایی که مطمئنیم نیازی به بررسی آن ها نیست
def redundent_chats(chat_id):
    if chat_id in ['5427116584','-4214311773', '6836232506',]:
        return True
    else:
        return False

# %% [markdown]
# ### trim_rows

# %%
# only keep the last message info
def trim_rows(max_elements=50):
    global previous_messages
    
    for i in range(len(previous_messages)):
        if len(previous_messages[i]) > max_elements:
            # حذف عناصر از عنصر دوم تا تعداد مورد نظر
            previous_messages[i] = [previous_messages[i][0]] + previous_messages[i][len(previous_messages[i]) - max_elements + 1:]

# %% [markdown]
# # Comunication

# %% [markdown]
# ### send_message_bot

# %%
# پیامی به چت خودم یا چت گروه هانتر می فرستند بر حسب اینکه پارامتر را هنگام فراخوانی چگونه ست کنیم
def send_message_bot(text, where = 'me'):
    token = '6836232506:AAEBdGfRFTbOVMePl2KZazyV4V0mglF29NM'
    chat_id = '7076137340'  #  آی دی خودم
    hunting_id = '-1002219036112'            #  آیدی گروه هانتینگ
    if(where != 'me'):
        chat_id = hunting_id
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    params = {'chat_id': chat_id, 'text': text}  # اصلاح 'hunting_id' به 'chat_id'
    response = requests.post(url, data=params)
    if response.status_code == 200:
        print(f"Message sent to {chat_id}: {text}")
    else:
        print(f"Failed to send message. Status code: {response.status_code}")

send_message_bot('test', 'group')
# Out:
# Message sent to -1002219036112: test

# %% [markdown]
# ### send_message

# %%
def send_message(message):
    close_super_group_button()
    hunting.click()
    time.sleep(1)
    input_box = driver.find_element(By.CSS_SELECTOR, 'div.input-message-input')
    # پاک کردن هر مقدار موجود در اینپوت باکس
    input_box.clear()  # ممکن است این متد بر روی المان‌های contenteditable کار نکند، بسته به نوع مرورگر
    # ارسال مقدار مورد نظر به اینپوت باکس
    input_box.send_keys(message)
    time.sleep(2)
    
    send_button = driver.find_element(By.CSS_SELECTOR, 'div.btn-send-container')  #  انتخاب دکمه ارسال
    send_button.click()
    
    
    # # در صورت نیاز به ارسال اینتر در انتها
    # time.sleep(2)
    # input_box.send_keys(Keys.RETURN)

# %% [markdown]
# ### log_error

# %%
def log_error(error_message):
    caller = inspect.stack()[1]
    try:
        with open('error_log.txt', 'a') as file:
            current_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            file.write(f"Time: {current_time}\n")
            file.write(f"Error in line <<< {caller.lineno} >>> of Function <<< {caller.function } >>>. \n")
            file.write(f"Error: {error_message}\n")
            file.write("\n" + "=*"*75 + "\n")
    except Exception as e:
        print(f"Failed to log error: {e}")

# %% [markdown]
# # Main Logic

# %% [markdown]
# ### survey_the_chat

# %%
#  در اینجا ما برای یک چت پیام ها را بررسی می کنیم که آیا موردی که مد نظرمان باشد یافت می شود یا خیر
def survey_the_chat(chat):
    global sending_messages, hunting, chat_id, timestamp, chat_title
    
    caller_function = inspect.currentframe().f_back.f_code.co_name    
    
    [chat_title, chat_id] = find_chat_title_and_id(chat)
    # if chat_id == '-2219036112':   # گروه هانتینگ 
    #     hunting = chat
    #     return
    
    if(redundent_chats(chat_id)):
        # print('redundent chat <- <- <- ', chat_title)
        return

    if(not(is_there_unread_message(chat))):
        return;   
                
    # print(f"Time {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} necessary chat -> -> -> ", chat_title)         
    scroll_down()
    converstion_list = driver.find_elements(By.CSS_SELECTOR, "div.bubbles-group")   # پیام هر کاربر در تگ با این کلاس هست
    for conversation in converstion_list:
        try:
            user_name = remove_html_and_patterns(conversation.find_element(By.CSS_SELECTOR, "span.peer-title").get_attribute("innerHTML"))
            message = remove_html_and_patterns(conversation.find_element(By.CSS_SELECTOR,"span.translatable-message").get_attribute("innerHTML"))
            timestamp = conversation.find_element(By.CSS_SELECTOR,'.is-in').get_attribute('data-timestamp')
            # data_peer_id = conversation.find_element(By.CSS_SELECTOR,'.is-in').get_attribute('data-peer-id')
        except:
            continue
        if (check_if_message_is_new()):
            if(text_processing(message)):
                for_sending = f" **نام گروه :** <<< {chat_title} >>> **نام کاربر : ** <<< {user_name} >>> **پیام کاربر :** : {message}"
                sending_messages.append(for_sending)
                print(' ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ ')
                print(' +++++++++++++++++++++++   WE GOT THE NEW FOLLOWING MESSAGE   +++++++++++++++++++++++++++ ')
                print(' ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ ')
                print(for_sending)

# %% [markdown]
# ### survey_the_sub_chats

# %%
def survey_the_sub_chats(mother_chat_title = 'unknown'):
    global sending_messages, chat_id, timestamp, chat_title
    cat_chats = find_list_of_all_sub_chats()
    for chat in cat_chats:
        if(True): #is_there_unread_message(chat)):              
            [sub_chat_title, chat_id] = find_sub_chat_title_and_id(chat)
            # print(f"Time {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} ================subgroup {sub_chat_title} of mother group {mother_chat_title}==========")
            chat_title = f"{sub_chat_title} ({mother_chat_title})"
            if clicking(chat):
                continue
            time.sleep(2)  # کمی صبر کنید تا عملیات کلیک و هر اتفاق بعد از آن انجام شود
            scroll_down()
            time.sleep(1)
            sub_converstion_list = driver.find_elements(By.CSS_SELECTOR, "div.bubbles-group") # پیام هر کاربر در تگ با این کلاس هست
            for conversation in sub_converstion_list:
                try:
                    user_name = remove_html_and_patterns(conversation.find_element(By.CSS_SELECTOR,"span.peer-title").text)
                    message = remove_html_and_patterns(conversation.find_element(By.CSS_SELECTOR,"span.translatable-message").text)
                    timestamp = conversation.find_element(By.CSS_SELECTOR,'div.is-in').get_attribute('data-timestamp')
                except Exception as e:
                    # print(f"**************************************Error: {e}")
                    continue
                    
                if (check_if_message_is_new()):
                    if(text_processing(message)):
                        for_sending = f" **نام گروه :** <<< {chat_title} >>> **نام کاربر : ** <<< {user_name} >>> **پیام کاربر :** : {message}"
                        sending_messages.append(for_sending)
    close_super_group_button()

# %% [markdown]
# ### once_check_all_groups

# %%
def once_check_all_groups():
    global hunting, sending_messages

    chats = find_list_of_all_chats()
    for chat in chats:
        [chat_title, chat_id] = find_chat_title_and_id(chat)
        chat.click()
        time.sleep(2)
        if  (is_a_super_group_open()):
            survey_the_sub_chats(chat_title)        
        else:
            survey_the_chat(chat)          

    try:
        print(f"               ********************  {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}  *************************")
        print('               *************************  END OF LOOP  ****************************')
        print('               ********************************************************************')
        print('')
        for message in sending_messages:
            message = clean_message(message)
            print('the current messages: +++++++++++++++++++++++++    ', message)
            send_message_bot(message, 'group')
            print('&&&&&&&&&&&&&&           THAT ONE SENT           &&&&&&&&&&&&&&&')
            print(f"Time {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} :\n"+message)
            time.sleep(4)
        if len(sending_messages) == 0:
            print('^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^')
        else:
            print('^^^^^^^^^^^^^^^^^^^^^^   ALL MESSAGES SUCCESSFULLY SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^')
            sending_messages = []  #  ریست کردن استورج جمع آوری پیام ها      
    except:
        print('%%%%%%%%%%%%%%%%%%%%%      there was a problem middle sending the messages and now we are in except part         %%%%%%%%%%%%%%%%%%%%%%%%%%%')
        print(' the message with problem is:')
        print(message)
        {} 
    trim_rows()  #  حذف اضافات ماتریس اطلاعات مسج های قبلی

# %% [markdown]
# ### main

# %% [markdown]
# def main():
#     # warm_up()
#     while True:
#         print('***********************  NEW ROUND  ****************************************')
#         once_check_all_groups()

# %% [markdown]
# # RUNNING TIME

# %%
def main():
    # warm_up()
    while True:
        print('               **************************  NEW ROUND  *****************************')

        once_check_all_groups()

if __name__ == "__main__":
    main()
# Out:
#                **************************  NEW ROUND  *****************************
# Message sent to 7076137340: من چند روز پیش مشاوره داشتم باهاتون میتونم پی وی چندتا سوال بپرسم ممنون میشم
# Message sent to 7076137340: سعيد امامى نژاد | مشاور رسمى املاك مشاور رسمی املاک در کلیه مناطق مونترال بزرگ و استان کبک فروش ، خرید ، اجاره و ساخت و ساز لاوال -وست آیلند-مونترال آیلند -سات شور، بروسارد -کندیاک لپرری-لانگوی وجنوب مونترال اجاره خانه و آپارتمان شما در کمترین زمان ممکن با کمترین هزینه فروش ملک شما با بالاترین قیمت تهیه وام بانکی با بهترین نرخ بهره(۵٪ پیش پرداخت-دان پیمنت) ارزیابی رایگان ملک مورد نظر شما-با کارشناسان ساختمان خدمات ۱۰۰٪ رایگان برای خریداران مشاور تخصصی و ارزیابی در زمینه املاک درآمدزا و سرمایه گذاری شماره تلفن:5145711772 اينستاگرام: IranianMontrealHome فيسبوك: Saeed.Emaminejad تلگرام Iranianmontrealhome سعید-امامی-نژاد
# Message sent to 7076137340: پیشنهاد ویژه: بیمه همراه دانشجو سعید به زودی دانشجوی دانشگاهی در کبک میشه. سعید متاهله و یک فرزند ۴ ساله داره. بر اساس تحقیقاتی که سعید انجام داده، مطمئن هست که نمی‌تونه برای کارت بیمه درمان استان کبک اقدام کنه. از طرف دانشگاه، فقط سعید بیمه میشه و اونم نگرانه که خدایی نکرده اگر اتفاق اورژانسی برای همسر و ‌فرزندش پیش بیاد، چطور باید هزینه‌های بالای درمان در کانادا پرداخت بشه. پس طی یک ‌جلسه مشاوره، سعید متوجه میشه که طبق قانون کبک، فرزندش واجد شرایط بیمه درمان استان هست، ولی برای همسر سعید، با اینکه دانشجو نبود، بیمه دانشجویی با کاوریج دو‌میلیون دلار خریداری شد. این پلن علاوه بر مزایای زیادی که در مقایسه به بیمه‌های رایج ویزیتوری داره، با یکی از بهترین سایت‌های آنلاین ویزیت پزشک کانادا طرف قرارداد هست. خبر خوش اینکه از اول جولای، سرویس ۲۴ ساعته و‌ هفت روز در هفته رایگان و محرمانه جهت مشاوره با روانشناس به سایر خدمات این پلن اضافه میشه. شما هم مثل همسر سعید اگر عضو درجه یک خانواده یک دانشجو یا دانش‌آموز هستید یا ورک پرمیت دارید و‌ در کلاس‌های رایگان فرانسه دولتی شرکت می‌کنید، از این فرصت ارزشمند بهره‌مند شوید. مریم طالبی مشاور رسمی بیمه و سرمایه‌گذاری فارغ التحصیل مدیریت مک‌گیل دسترسی به کمپانی‌های بزرگ کانادایی بیمه‌ی عمر بیمه عمر و‌ سرمایه‌گذاری بیمه مورگج (وام مسکن ) بیمه از کار افتادگی بیمه بیماریهای خاص انواع بیمه های مسافرتی شامل دانشجویی، دانش‌آموزی، همراه دانشجو، ویزیتوری و سوپرویزا (با شرایط پرداخت اقساطی ) حساب تحصیلی فرزندان RESP حساب پس‌انداز بازنشستگی RRSP حساب معاف از مالیات TFSA حساب خریداران خانه اول FHSA پکیج بیمه‌ی تکمیلی بیمه‌ی مسئولیت برای مشاغل کوچک شماره تماس برای مشاوره رایگان: (514)993-7976 اینستاگرام
#                ********************  2024-06-30 22:01:56  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:04:15  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:06:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:09:04  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:11:28  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:13:48  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:16:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:18:26  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:20:45  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:23:04  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:25:23  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:27:42  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:30:02  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:32:23  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:34:41  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:37:01  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:39:22  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:41:42  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:44:03  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:46:23  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:48:44  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:51:04  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:53:25  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:55:46  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 22:58:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:00:29  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:02:51  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:05:15  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:07:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:10:00  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:12:26  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:14:48  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:17:13  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:19:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:22:03  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:24:25  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:26:46  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:29:09  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:31:37  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:33:58  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:36:22  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:38:49  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:41:13  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:43:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:46:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:48:33  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:51:00  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:53:28  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:55:55  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-06-30 23:58:19  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:00:47  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:03:11  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:05:41  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:08:08  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:10:32  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:12:57  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:15:30  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:17:57  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:20:25  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:22:54  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:25:25  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:27:53  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:30:22  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:32:52  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:35:27  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:37:57  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:40:31  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:43:00  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:45:36  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:48:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:50:34  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:53:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:55:40  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 00:58:14  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:00:52  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:03:24  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:05:56  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:08:32  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:11:06  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:13:42  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:16:17  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:18:59  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:21:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:24:13  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:26:57  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:29:32  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:32:05  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:34:55  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:37:34  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:40:09  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:42:50  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:45:31  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:48:22  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:51:06  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:53:49  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:56:34  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 01:59:14  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:01:56  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:04:38  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  +++++++++++++++++++++++   WE GOT THE NEW FOLLOWING MESSAGE   +++++++++++++++++++++++++++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Ma >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  +++++++++++++++++++++++   WE GOT THE NEW FOLLOWING MESSAGE   +++++++++++++++++++++++++++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Mina >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  +++++++++++++++++++++++   WE GOT THE NEW FOLLOWING MESSAGE   +++++++++++++++++++++++++++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< shakila shafienia >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# Message sent to 7076137340: دوستان من امروز با مهشید جون وقت مشاوره داشتم برای pr و نمیتونم بگم چقدر خوب، مسلط، دقیق و دلسوز بود...
#                ********************  2024-07-01 02:07:29  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# the current messages: +++++++++++++++++++++++++     **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Ma >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# Message sent to -1002219036112: **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Ma >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# &&&&&&&&&&&&&&           THAT ONE SENT           &&&&&&&&&&&&&&&
# Time 2024-07-01 02:07:30 :
# **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Ma >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# the current messages: +++++++++++++++++++++++++     **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Mina >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# Message sent to -1002219036112: **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Mina >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# &&&&&&&&&&&&&&           THAT ONE SENT           &&&&&&&&&&&&&&&
# Time 2024-07-01 02:07:34 :
# **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< Mina >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# the current messages: +++++++++++++++++++++++++     **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< shakila shafienia >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# Message sent to -1002219036112: **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< shakila shafienia >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# &&&&&&&&&&&&&&           THAT ONE SENT           &&&&&&&&&&&&&&&
# Time 2024-07-01 02:07:39 :
# **نام گروه :** <<< New Policy | Canada >>> **نام کاربر : ** <<< shakila shafienia >>> **پیام کاربر :** : قبلا یه بار ریجکت شدم وکیلمو عوض کردم تقریبا ۵۰ روزه
# ^^^^^^^^^^^^^^^^^^^^^^   ALL MESSAGES SUCCESSFULLY SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:10:28  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:13:14  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:16:04  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:18:43  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:21:28  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:24:25  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:27:12  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:30:00  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:32:50  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:35:57  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:38:55  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:41:41  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:44:26  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:47:19  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
# Message sent to 7076137340: گروه پذیرش تحصیلی کانادا و آمریکا مشاوره و راهنمایی در خصوص انتخاب دانشگاه شرایط دانشگاه ها برای انتخاب دانشجو انتخاب بهترین مقصد دانشجویی لینک گروه: @AdmissionComma لطفا دوستانتان را به گروه پذیرش تحصیلی کانادا و آمریکا دعوت کنید
# Message sent to 7076137340: کسی در ونکور میشناسید مشاور تخصصی بده یا فرم رو پر کنه؟
# Message sent to 7076137340: سلام و وقت به خیر، برای چه مواردی پیشنهاد میکنید که به یک نفر از نزدیکان در ایران وکالت بدیم؟ مثلا وکالت فروش ملک و دیگه چه مواردی ممکنه نیاز باشه که وکیلی در ایران داشته باشیم؟
# Message sent to 7076137340: من چند روز پیش مشاوره داشتم باهاتون میتونم پی وی چندتا سوال بپرسم ممنون میشم
# Message sent to 7076137340: دوستان من امروز با مهشید جون وقت مشاوره داشتم برای pr و نمیتونم بگم چقدر خوب، مسلط، دقیق و دلسوز بود...
#                ********************  2024-07-01 02:50:28  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:53:12  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:56:15  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 02:59:14  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:02:09  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:05:01  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:08:01  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:10:51  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:13:47  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:17:04  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:20:07  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:23:09  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:26:02  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************
#                ********************  2024-07-01 03:29:05  *************************
#                *************************  END OF LOOP  ****************************
#                ********************************************************************
#
# ^^^^^^^^^^^^^^^^^^^^^^   THERE WAS NO MESSAGE TO SENT   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#                **************************  NEW ROUND  *****************************

# %% [markdown]
# #  تستی

# %%
# sending_messages=[]
# previous_messages=[]
